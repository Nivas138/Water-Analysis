# %%
import pandas as pd
import numpy as nump
import matplotlib.pyplot as plt
import csv
import plotly.graph_objs as go
import plotly.plotly as py

from plotly import tools
import datetime

# %%
df = pd.read_csv("chennai_reservoir_levels.csv")
df
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# 5     06-01-2004     3.8         0.0     266.0              0.0
# 6     07-01-2004     3.8         0.0     266.0              0.0
# 7     08-01-2004     3.7         0.0     265.0              0.0
# 8     09-01-2004     3.7         0.0     264.0              0.0
# 9     10-01-2004     3.7         0.0     264.0              0.0
# 10    11-01-2004     3.6         0.0     263.0              0.0
# 11    12-01-2004     3.6         0.0     262.0              0.0
# 12    13-01-2004     3.6         0.0     261.0              0.0
# 13    14-01-2004     3.5         0.0     260.0              0.0
# ...

# %%
axes = plt.gca()
axes.set_xlim(['01-01-2004','17-06-2019'])
axes.set_ylim(['0.0','500.00'])
# Out:
# (array([0.]), array([1.]))

# %%
df1 = df.filter(['Date','POONDI'],axis=1)
df2 = df.filter(['Date','CHOLAVARAM'],axis=1)
df3 = df.filter(['Date','REDHILLS'],axis=1)
df4 = df.filter(['Date','CHEMBARAMBAKKAM'],axis=1)

# %%
df1.set_index('Date').plot(figsize=(15,6), grid=True,color='blue',kind='area')
df2.set_index('Date').plot(figsize=(15,6),grid=True,color='green',kind='area')
df3.set_index('Date').plot(figsize=(15,6),grid=True,color='red',kind='area')
df4.set_index('Date').plot(figsize=(15,6),grid=True,color='orange',kind='area')

# %%
df1['POODNI'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\notebook\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POODNI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-2bcf1911178c> in <module>
# ----> 1 df1['POODNI'].sum()
#
# ...

# %%
plt.axis(['01-01-2004','17-06-2019','0.0','500.0'])
plt.xlabel('DATE')
plt.ylabel('Water Analysis')
plt.title('Chennai Reservoir Capacity Level')
# Out:
# Text(0.5, 1.0, 'Chennai Reservoir Capacity Level')

# %%
df.shape
# Out:
# (5647, 5)

# %%
# Out:
# pandas.core.series.Series
